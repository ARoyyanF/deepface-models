# %%
# %pip install -U onnx==1.17.0 
# %pip install -U nvidia-pyindex 
# %pip install -U onnx-graphsurgeon
# %pip install -U onnxruntime==1.18.1
# %pip install -U onnxsim==0.4.33
# %pip install -U simple_onnx_processing_tools
# %pip install -U sne4onnx>=1.0.13
# %pip install -U sng4onnx>=1.0.4
# %pip install -U ai_edge_litert==1.2.0
# %pip install -U tensorflow==2.19.0
# %pip install -U protobuf==3.20.3
# %pip install -U onnx2tf
# %pip install -U h5py==3.11.0
# %pip install -U psutil==5.9.5
# %pip install -U ml_dtypes==0.5.1
# %pip install -U tf-keras==2.19.0
# %pip install flatbuffers>=23.5.26
# Out:
# Collecting onnx==1.17.0
#   Using cached onnx-1.17.0-cp312-cp312-win_amd64.whl.metadata (16 kB)
# Requirement already satisfied: numpy>=1.20 in c:\arf\my-repos\magang\.venv\lib\site-packages (from onnx==1.17.0) (2.1.3)
# Requirement already satisfied: protobuf>=3.20.2 in c:\arf\my-repos\magang\.venv\lib\site-packages (from onnx==1.17.0) (5.29.5)
# Using cached onnx-1.17.0-cp312-cp312-win_amd64.whl (14.5 MB)
# Installing collected packages: onnx
#   Attempting uninstall: onnx
#     Found existing installation: onnx 1.18.0
#     Uninstalling onnx-1.18.0:
#       Successfully uninstalled onnx-1.18.0
# Successfully installed onnx-1.17.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'C:\ARF\my-repos\magang\.venv\Lib\site-packages\~nnx'.
#   You can safely remove it manually.
# Collecting nvidia-pyindex
#   Downloading nvidia-pyindex-1.0.9.tar.gz (10 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: nvidia-pyindex
#   Building wheel for nvidia-pyindex (setup.py): started
#   Building wheel for nvidia-pyindex (setup.py): finished with status 'done'
#   Created wheel for nvidia-pyindex: filename=nvidia_pyindex-1.0.9-py3-none-any.whl size=8528 sha256=56f48afc448a09ed3f0b5982fe026c833de83a5e28ca92ca5b3eab9bb2dd6704
#   Stored in directory: c:\users\aroyy\appdata\local\pip\cache\wheels\eb\2d\7f\d86cb060a9c51fb933aa4fe0d2f73ffe8df2bd0b58d3d2bba4
# Successfully built nvidia-pyindex
# Installing collected packages: nvidia-pyindex
# Successfully installed nvidia-pyindex-1.0.9
# Note: you may need to restart the kernel to use updated packages.
#   DEPRECATION: Building 'nvidia-pyindex' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'nvidia-pyindex'. Discussion can be found at https://github.com/pypa/pip/issues/6334
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: onnx-graphsurgeon in c:\arf\my-repos\magang\.venv\lib\site-packages (0.5.8)
# Requirement already satisfied: numpy in c:\arf\my-repos\magang\.venv\lib\site-packages (from onnx-graphsurgeon) (2.1.3)
# Requirement already satisfied: onnx>=1.14.0 in c:\arf\my-repos\magang\.venv\lib\site-packages (from onnx-graphsurgeon) (1.17.0)
# Requirement already satisfied: protobuf>=3.20.2 in c:\arf\my-repos\magang\.venv\lib\site-packages (from onnx>=1.14.0->onnx-graphsurgeon) (5.29.5)
# Note: you may need to restart the kernel to use updated packages.
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting onnxruntime==1.18.1
#   Downloading onnxruntime-1.18.1-cp312-cp312-win_amd64.whl.metadata (4.5 kB)
# Collecting coloredlogs (from onnxruntime==1.18.1)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in c:\arf\my-repos\magang\.venv\lib\site-packages (from onnxruntime==1.18.1) (25.2.10)
# Collecting numpy<2.0,>=1.21.6 (from onnxruntime==1.18.1)
#   Downloading numpy-1.26.4-cp312-cp312-win_amd64.whl.metadata (61 kB)
# Requirement already satisfied: packaging in c:\arf\my-repos\magang\.venv\lib\site-packages (from onnxruntime==1.18.1) (25.0)
# Requirement already satisfied: protobuf in c:\arf\my-repos\magang\.venv\lib\site-packages (from onnxruntime==1.18.1) (5.29.5)
# Requirement already satisfied: sympy in c:\arf\my-repos\magang\.venv\lib\site-packages (from onnxruntime==1.18.1) (1.14.0)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime==1.18.1)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Collecting pyreadline3 (from humanfriendly>=9.1->coloredlogs->onnxruntime==1.18.1)
#   Downloading pyreadline3-3.5.4-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\arf\my-repos\magang\.venv\lib\site-packages (from sympy->onnxruntime==1.18.1) (1.3.0)
# Downloading onnxruntime-1.18.1-cp312-cp312-win_amd64.whl (5.6 MB)
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ------------- -------------------------- 1.8/5.6 MB 11.2 MB/s eta 0:00:01
#    ------------------------------ --------- 4.2/5.6 MB 11.5 MB/s eta 0:00:01
#    ---------------------------------------- 5.6/5.6 MB 12.2 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp312-cp312-win_amd64.whl (15.5 MB)
#    ---------------------------------------- 0.0/15.5 MB ? eta -:--:--
#    ------- -------------------------------- 2.9/15.5 MB 14.0 MB/s eta 0:00:01
#    ------------ --------------------------- 4.7/15.5 MB 11.9 MB/s eta 0:00:01
#    ------------------ --------------------- 7.1/15.5 MB 11.5 MB/s eta 0:00:01
#    ----------------------- ---------------- 9.2/15.5 MB 11.0 MB/s eta 0:00:01
#    ------------------------------- -------- 12.3/15.5 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------  15.2/15.5 MB 12.3 MB/s eta 0:00:01
#    ---------------------------------------- 15.5/15.5 MB 12.4 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Downloading pyreadline3-3.5.4-py3-none-any.whl (83 kB)
# Installing collected packages: pyreadline3, numpy, humanfriendly, coloredlogs, onnxruntime
#
#    ---------------------------------------- 0/5 [pyreadline3]
#    ---------------------------------------- 0/5 [pyreadline3]
#    ---------------------------------------- 0/5 [pyreadline3]
#   Attempting uninstall: numpy
#    ---------------------------------------- 0/5 [pyreadline3]
#     Found existing installation: numpy 2.1.3
#    ---------------------------------------- 0/5 [pyreadline3]
#     Uninstalling numpy-2.1.3:
#    ---------------------------------------- 0/5 [pyreadline3]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#       Successfully uninstalled numpy-2.1.3
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    ---------------- ----------------------- 2/5 [humanfriendly]
#    ---------------- ----------------------- 2/5 [humanfriendly]
#    ------------------------ --------------- 3/5 [coloredlogs]
#    ------------------------ --------------- 3/5 [coloredlogs]
#    -------------------------------- ------- 4/5 [onnxruntime]
#    -------------------------------- ------- 4/5 [onnxruntime]
#    -------------------------------- ------- 4/5 [onnxruntime]
#    -------------------------------- ------- 4/5 [onnxruntime]
#    -------------------------------- ------- 4/5 [onnxruntime]
#    -------------------------------- ------- 4/5 [onnxruntime]
#    -------------------------------- ------- 4/5 [onnxruntime]
#    -------------------------------- ------- 4/5 [onnxruntime]
#    -------------------------------- ------- 4/5 [onnxruntime]
#    -------------------------------- ------- 4/5 [onnxruntime]
#    -------------------------------- ------- 4/5 [onnxruntime]
#    -------------------------------- ------- 4/5 [onnxruntime]
#    -------------------------------- ------- 4/5 [onnxruntime]
#    -------------------------------- ------- 4/5 [onnxruntime]
#    -------------------------------- ------- 4/5 [onnxruntime]
#    -------------------------------- ------- 4/5 [onnxruntime]
#    -------------------------------- ------- 4/5 [onnxruntime]
#    -------------------------------- ------- 4/5 [onnxruntime]
#    -------------------------------- ------- 4/5 [onnxruntime]
#    -------------------------------- ------- 4/5 [onnxruntime]
#    -------------------------------- ------- 4/5 [onnxruntime]
#    -------------------------------- ------- 4/5 [onnxruntime]
#    -------------------------------- ------- 4/5 [onnxruntime]
#    -------------------------------- ------- 4/5 [onnxruntime]
#    -------------------------------- ------- 4/5 [onnxruntime]
#    ---------------------------------------- 5/5 [onnxruntime]
#
# Successfully installed coloredlogs-15.0.1 humanfriendly-10.0 numpy-1.26.4 onnxruntime-1.18.1 pyreadline3-3.5.4
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'C:\ARF\my-repos\magang\.venv\Lib\site-packages\~umpy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\ARF\my-repos\magang\.venv\Lib\site-packages\~umpy'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting onnxsim==0.4.33
#   Downloading onnxsim-0.4.33.tar.gz (20.1 MB)
#      ---------------------------------------- 0.0/20.1 MB ? eta -:--:--
#      --- ------------------------------------ 1.8/20.1 MB 12.6 MB/s eta 0:00:02
#      ------ --------------------------------- 3.1/20.1 MB 14.1 MB/s eta 0:00:02
#      -------- ------------------------------- 4.2/20.1 MB 10.5 MB/s eta 0:00:02
#      -------- ------------------------------- 4.2/20.1 MB 10.5 MB/s eta 0:00:02
#      ----------- ---------------------------- 6.0/20.1 MB 6.1 MB/s eta 0:00:03
#      --------------- ------------------------ 7.9/20.1 MB 6.8 MB/s eta 0:00:02
#      ---------------------- ----------------- 11.3/20.1 MB 8.1 MB/s eta 0:00:02
#      ----------------------------- ---------- 14.7/20.1 MB 9.1 MB/s eta 0:00:01
#      ---------------------------------- ----- 17.6/20.1 MB 9.8 MB/s eta 0:00:01
#      --------------------------------------  19.9/20.1 MB 10.0 MB/s eta 0:00:01
#      ---------------------------------------- 20.1/20.1 MB 9.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: onnx in c:\arf\my-repos\magang\.venv\lib\site-packages (from onnxsim==0.4.33) (1.17.0)
# Requirement already satisfied: rich in c:\arf\my-repos\magang\.venv\lib\site-packages (from onnxsim==0.4.33) (14.0.0)
# Requirement already satisfied: numpy>=1.20 in c:\arf\my-repos\magang\.venv\lib\site-packages (from onnx->onnxsim==0.4.33) (1.26.4)
# Requirement already satisfied: protobuf>=3.20.2 in c:\arf\my-repos\magang\.venv\lib\site-packages (from onnx->onnxsim==0.4.33) (5.29.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\arf\my-repos\magang\.venv\lib\site-packages (from rich->onnxsim==0.4.33) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\arf\my-repos\magang\.venv\lib\site-packages (from rich->onnxsim==0.4.33) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\arf\my-repos\magang\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich->onnxsim==0.4.33) (0.1.2)
# Building wheels for collected packages: onnxsim
#   Building wheel for onnxsim (setup.py): started
#   Building wheel for onnxsim (setup.py): finished with status 'error'
#   Running setup.py clean for onnxsim
# Failed to build onnxsim
# Note: you may need to restart the kernel to use updated packages.
#   DEPRECATION: Building 'onnxsim' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'onnxsim'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [172 lines of output]
#       C:\Users\aroyy\AppData\Local\Temp\pip-install-xbznc15k\onnxsim_f9e7dbf3d0d94f17b15951aa4d0560ab\setup.py:28: DeprecationWarning: Use shutil.which instead of find_executable
#         CMAKE = find_executable('cmake')
#       fatal: not a git repository (or any of the parent directories): .git
#       fatal: not a git repository (or any of the parent directories): .git
#       c:\ARF\my-repos\magang\.venv\Lib\site-packages\setuptools\__init__.py:92: _DeprecatedInstaller: setuptools.installer and fetch_build_eggs are deprecated.
#       !!
#
#               ********************************************************************************
#               Requirements should be satisfied by a PEP 517 installer.
#               If you are using pip, you can try `pip install --use-pep517`.
#
#               By 2025-Oct-31, you need to update your project and remove deprecated calls
#               or your builds will no longer be supported.
#               ********************************************************************************
#
#       !!
#         dist.fetch_build_eggs(dist.setup_requires)
#       c:\ARF\my-repos\magang\.venv\Lib\site-packages\setuptools\dist.py:759: SetuptoolsDeprecationWarning: License classifiers are deprecated.
#       !!
#
#               ********************************************************************************
#               Please consider removing the following classifiers in favor of a SPDX license expression:
#
#               License :: OSI Approved :: Apache Software License
#
#               See https://packaging.python.org/en/latest/guides/writing-pyproject-toml/#license for details.
#               ********************************************************************************
#
#       !!
#         self._finalize_license_expression()
#       running bdist_wheel
#       running build
#       running build_py
#       running create_version
#       creating build\lib.win-amd64-cpython-312\onnxsim
#       copying onnxsim\model_checking.py -> build\lib.win-amd64-cpython-312\onnxsim
#       copying onnxsim\model_info.py -> build\lib.win-amd64-cpython-312\onnxsim
#       copying onnxsim\onnx_simplifier.py -> build\lib.win-amd64-cpython-312\onnxsim
#       copying onnxsim\version.py -> build\lib.win-amd64-cpython-312\onnxsim
#       copying onnxsim\__init__.py -> build\lib.win-amd64-cpython-312\onnxsim
#       copying onnxsim\__main__.py -> build\lib.win-amd64-cpython-312\onnxsim
#       running egg_info
#       writing onnxsim.egg-info\PKG-INFO
#       writing dependency_links to onnxsim.egg-info\dependency_links.txt
#       writing entry points to onnxsim.egg-info\entry_points.txt
#       writing requirements to onnxsim.egg-info\requires.txt
#       writing top-level names to onnxsim.egg-info\top_level.txt
#       reading manifest file 'onnxsim.egg-info\SOURCES.txt'
#       reading manifest template 'MANIFEST.in'
#       warning: no files found matching '*.c' under directory 'onnxsim'
#       warning: no files found matching '*.proto' under directory 'onnxsim'
#       warning: no previously-included files matching '*' found under directory 'third_party\onnxruntime'
#       warning: no previously-included files matching '*' found under directory 'third_party\onnx-optimizer\build'
#       warning: no previously-included files matching '*' found under directory 'third_party\onnx\build'
#       warning: no previously-included files matching '*' found under directory 'third_party\onnx\onnx\backend'
#       adding license file 'LICENSE'
#       writing manifest file 'onnxsim.egg-info\SOURCES.txt'
#       c:\ARF\my-repos\magang\.venv\Lib\site-packages\setuptools\command\build_py.py:212: _Warning: Package 'onnxsim.bin' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'onnxsim.bin' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'onnxsim.bin' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'onnxsim.bin' to be distributed and are
#               already explicitly excluding 'onnxsim.bin' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       copying onnxsim\cpp2py_export.cc -> build\lib.win-amd64-cpython-312\onnxsim
#       copying onnxsim\cxxopts.hpp -> build\lib.win-amd64-cpython-312\onnxsim
#       copying onnxsim\onnxsim.cpp -> build\lib.win-amd64-cpython-312\onnxsim
#       copying onnxsim\onnxsim.h -> build\lib.win-amd64-cpython-312\onnxsim
#       creating build\lib.win-amd64-cpython-312\onnxsim\bin
#       copying onnxsim\bin\onnxsim_bin.cpp -> build\lib.win-amd64-cpython-312\onnxsim\bin
#       copying onnxsim\bin\onnxsim_option.cpp -> build\lib.win-amd64-cpython-312\onnxsim\bin
#       copying onnxsim\bin\onnxsim_option.h -> build\lib.win-amd64-cpython-312\onnxsim\bin
#       running build_ext
#       running cmake_build
#       Run command ['C:\\Strawberry\\c\\bin\\cmake.exe', '-DPython_INCLUDE_DIR=C:\\Users\\aroyy\\AppData\\Local\\Programs\\Python\\Python312\\include', '-DPython_EXECUTABLE=c:\\ARF\\my-repos\\magang\\.venv\\Scripts\\python.exe', '-DPYTHON_EXECUTABLE=c:\\ARF\\my-repos\\magang\\.venv\\Scripts\\python.exe', '-DBUILD_ONNX_PYTHON=OFF', '-DONNXSIM_PYTHON=ON', '-DONNXSIM_BUILTIN_ORT=OFF', '-DONNX_USE_LITE_PROTO=OFF', '-DCMAKE_EXPORT_COMPILE_COMMANDS=ON', '-DONNX_NAMESPACE=onnx', '-DPY_EXT_SUFFIX=.cp312-win_amd64.pyd', '-DONNX_OPT_USE_SYSTEM_PROTOBUF=OFF', '-DCMAKE_BUILD_TYPE=Release', '-DPY_VERSION=3.12', '-A', 'x64', '-T', 'host=x64', '-DONNX_ML=1', 'C:\\Users\\aroyy\\AppData\\Local\\Temp\\pip-install-xbznc15k\\onnxsim_f9e7dbf3d0d94f17b15951aa4d0560ab']
#       -- Building for: Ninja
#       CMake Error at CMakeLists.txt:9 (project):
#         Generator
#
#           Ninja
#
#         does not support platform specification, but platform
#
#           x64
#
#         was specified.
#
#
#       CMake Error: CMAKE_CXX_COMPILER not set, after EnableLanguage
#       -- Configuring incomplete, errors occurred!
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 35, in <module>
#         File "C:\Users\aroyy\AppData\Local\Temp\pip-install-xbznc15k\onnxsim_f9e7dbf3d0d94f17b15951aa4d0560ab\setup.py", line 279, in <module>
#           setuptools.setup(
#         File "c:\ARF\my-repos\magang\.venv\Lib\site-packages\setuptools\__init__.py", line 115, in setup
#           return distutils.core.setup(**attrs)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "c:\ARF\my-repos\magang\.venv\Lib\site-packages\setuptools\_distutils\core.py", line 186, in setup
#           return run_commands(dist)
#                  ^^^^^^^^^^^^^^^^^^
#         File "c:\ARF\my-repos\magang\.venv\Lib\site-packages\setuptools\_distutils\core.py", line 202, in run_commands
#           dist.run_commands()
#         File "c:\ARF\my-repos\magang\.venv\Lib\site-packages\setuptools\_distutils\dist.py", line 1002, in run_commands
#           self.run_command(cmd)
#         File "c:\ARF\my-repos\magang\.venv\Lib\site-packages\setuptools\dist.py", line 1102, in run_command
#           super().run_command(command)
#         File "c:\ARF\my-repos\magang\.venv\Lib\site-packages\setuptools\_distutils\dist.py", line 1021, in run_command
#           cmd_obj.run()
#         File "c:\ARF\my-repos\magang\.venv\Lib\site-packages\setuptools\command\bdist_wheel.py", line 370, in run
#           self.run_command("build")
#         File "c:\ARF\my-repos\magang\.venv\Lib\site-packages\setuptools\_distutils\cmd.py", line 357, in run_command
#           self.distribution.run_command(command)
#         File "c:\ARF\my-repos\magang\.venv\Lib\site-packages\setuptools\dist.py", line 1102, in run_command
#           super().run_command(command)
#         File "c:\ARF\my-repos\magang\.venv\Lib\site-packages\setuptools\_distutils\dist.py", line 1021, in run_command
#           cmd_obj.run()
#         File "c:\ARF\my-repos\magang\.venv\Lib\site-packages\setuptools\_distutils\command\build.py", line 135, in run
#           self.run_command(cmd_name)
#         File "c:\ARF\my-repos\magang\.venv\Lib\site-packages\setuptools\_distutils\cmd.py", line 357, in run_command
#           self.distribution.run_command(command)
#         File "c:\ARF\my-repos\magang\.venv\Lib\site-packages\setuptools\dist.py", line 1102, in run_command
#           super().run_command(command)
#         File "c:\ARF\my-repos\magang\.venv\Lib\site-packages\setuptools\_distutils\dist.py", line 1021, in run_command
#           cmd_obj.run()
#         File "C:\Users\aroyy\AppData\Local\Temp\pip-install-xbznc15k\onnxsim_f9e7dbf3d0d94f17b15951aa4d0560ab\setup.py", line 220, in run
#           self.run_command('cmake_build')
#         File "c:\ARF\my-repos\magang\.venv\Lib\site-packages\setuptools\_distutils\cmd.py", line 357, in run_command
#           self.distribution.run_command(command)
#         File "c:\ARF\my-repos\magang\.venv\Lib\site-packages\setuptools\dist.py", line 1102, in run_command
#           super().run_command(command)
#         File "c:\ARF\my-repos\magang\.venv\Lib\site-packages\setuptools\_distutils\dist.py", line 1021, in run_command
#           cmd_obj.run()
#         File "C:\Users\aroyy\AppData\Local\Temp\pip-install-xbznc15k\onnxsim_f9e7dbf3d0d94f17b15951aa4d0560ab\setup.py", line 194, in run
#           subprocess.check_call(cmake_args)
#         File "C:\Users\aroyy\AppData\Local\Programs\Python\Python312\Lib\subprocess.py", line 413, in check_call
#           raise CalledProcessError(retcode, cmd)
#       subprocess.CalledProcessError: Command '['C:\\Strawberry\\c\\bin\\cmake.exe', '-DPython_INCLUDE_DIR=C:\\Users\\aroyy\\AppData\\Local\\Programs\\Python\\Python312\\include', '-DPython_EXECUTABLE=c:\\ARF\\my-repos\\magang\\.venv\\Scripts\\python.exe', '-DPYTHON_EXECUTABLE=c:\\ARF\\my-repos\\magang\\.venv\\Scripts\\python.exe', '-DBUILD_ONNX_PYTHON=OFF', '-DONNXSIM_PYTHON=ON', '-DONNXSIM_BUILTIN_ORT=OFF', '-DONNX_USE_LITE_PROTO=OFF', '-DCMAKE_EXPORT_COMPILE_COMMANDS=ON', '-DONNX_NAMESPACE=onnx', '-DPY_EXT_SUFFIX=.cp312-win_amd64.pyd', '-DONNX_OPT_USE_SYSTEM_PROTOBUF=OFF', '-DCMAKE_BUILD_TYPE=Release', '-DPY_VERSION=3.12', '-A', 'x64', '-T', 'host=x64', '-DONNX_ML=1', 'C:\\Users\\aroyy\\AppData\\Local\\Temp\\pip-install-xbznc15k\\onnxsim_f9e7dbf3d0d94f17b15951aa4d0560ab']' returned non-zero exit status 1.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for onnxsim
# ERROR: Failed to build installable wheels for some pyproject.toml based projects (onnxsim)
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting simple_onnx_processing_tools
#   Downloading simple_onnx_processing_tools-1.1.32-py3-none-any.whl.metadata (21 kB)
# Collecting snc4onnx>=1.0.12 (from simple_onnx_processing_tools)
#   Downloading snc4onnx-1.0.13-py3-none-any.whl.metadata (11 kB)
# Collecting sne4onnx>=1.0.11 (from simple_onnx_processing_tools)
#   Downloading sne4onnx-1.0.13-py3-none-any.whl.metadata (7.0 kB)
# Collecting snd4onnx>=1.1.6 (from simple_onnx_processing_tools)
#   Downloading snd4onnx-1.1.6-py3-none-any.whl.metadata (6.0 kB)
# Collecting scs4onnx>=1.0.18 (from simple_onnx_processing_tools)
#   Downloading scs4onnx-1.0.18-py3-none-any.whl.metadata (12 kB)
# Collecting sog4onnx>=1.0.16 (from simple_onnx_processing_tools)
#   Downloading sog4onnx-1.0.17-py3-none-any.whl.metadata (11 kB)
# Collecting sam4onnx>=1.0.14 (from simple_onnx_processing_tools)
#   Downloading sam4onnx-1.0.16-py3-none-any.whl.metadata (11 kB)
# Collecting soc4onnx>=1.0.2 (from simple_onnx_processing_tools)
#   Downloading soc4onnx-1.0.2-py3-none-any.whl.metadata (4.2 kB)
# Collecting scc4onnx>=1.0.5 (from simple_onnx_processing_tools)
#   Downloading scc4onnx-1.0.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting sna4onnx>=1.0.6 (from simple_onnx_processing_tools)
#   Downloading sna4onnx-1.0.6-py3-none-any.whl.metadata (13 kB)
# Collecting sbi4onnx>=1.0.5 (from simple_onnx_processing_tools)
#   Downloading sbi4onnx-1.0.7-py3-none-any.whl.metadata (6.5 kB)
# Collecting sor4onnx>=1.0.5 (from simple_onnx_processing_tools)
#   Downloading sor4onnx-1.0.7-py3-none-any.whl.metadata (6.5 kB)
# Collecting sit4onnx>=1.0.7 (from simple_onnx_processing_tools)
#   Downloading sit4onnx-1.0.8-py3-none-any.whl.metadata (15 kB)
# Collecting onnx2json>=2.0.4 (from simple_onnx_processing_tools)
#   Downloading onnx2json-2.0.4-py3-none-any.whl.metadata (3.5 kB)
# Collecting json2onnx>=2.0.3 (from simple_onnx_processing_tools)
#   Downloading json2onnx-2.0.3-py3-none-any.whl.metadata (3.3 kB)
# Collecting sed4onnx>=1.0.5 (from simple_onnx_processing_tools)
#   Downloading sed4onnx-1.0.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting soa4onnx>=1.0.4 (from simple_onnx_processing_tools)
#   Downloading soa4onnx-1.0.4-py3-none-any.whl.metadata (5.7 kB)
# Collecting sod4onnx>=1.0.0 (from simple_onnx_processing_tools)
#   Downloading sod4onnx-1.0.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting ssi4onnx>=1.0.2 (from simple_onnx_processing_tools)
#   Downloading ssi4onnx-1.0.4-py3-none-any.whl.metadata (4.2 kB)
# Collecting ssc4onnx>=1.0.5 (from simple_onnx_processing_tools)
#   Downloading ssc4onnx-1.0.8-py3-none-any.whl.metadata (3.8 kB)
# Collecting sio4onnx>=1.0.2 (from simple_onnx_processing_tools)
#   Downloading sio4onnx-1.0.3-py3-none-any.whl.metadata (7.7 kB)
# Collecting svs4onnx>=1.0.0 (from simple_onnx_processing_tools)
#   Downloading svs4onnx-1.0.0-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: onnx2tf>=1.20.1 in c:\arf\my-repos\magang\.venv\lib\site-packages (from simple_onnx_processing_tools) (1.28.2)
# Collecting sng4onnx>=1.0.2 (from simple_onnx_processing_tools)
#   Downloading sng4onnx-1.0.4-py3-none-any.whl.metadata (4.6 kB)
# Collecting sde4onnx>=1.0.0 (from simple_onnx_processing_tools)
#   Downloading sde4onnx-1.0.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting spo4onnx>=1.0.4 (from simple_onnx_processing_tools)
#   Downloading spo4onnx-1.0.5-py3-none-any.whl.metadata (8.9 kB)
# Downloading simple_onnx_processing_tools-1.1.32-py3-none-any.whl (7.8 kB)
# Downloading json2onnx-2.0.3-py3-none-any.whl (5.0 kB)
# Downloading onnx2json-2.0.4-py3-none-any.whl (5.0 kB)
# Downloading sam4onnx-1.0.16-py3-none-any.whl (11 kB)
# Downloading sbi4onnx-1.0.7-py3-none-any.whl (6.9 kB)
# Downloading scc4onnx-1.0.7-py3-none-any.whl (9.7 kB)
# Downloading scs4onnx-1.0.18-py3-none-any.whl (10 kB)
# Downloading sde4onnx-1.0.0-py3-none-any.whl (5.5 kB)
# Downloading sed4onnx-1.0.5-py3-none-any.whl (5.7 kB)
# Downloading sio4onnx-1.0.3-py3-none-any.whl (8.0 kB)
# Downloading sit4onnx-1.0.8-py3-none-any.whl (11 kB)
# Downloading sna4onnx-1.0.6-py3-none-any.whl (10 kB)
# Downloading snc4onnx-1.0.13-py3-none-any.whl (10 kB)
# Downloading snd4onnx-1.1.6-py3-none-any.whl (9.0 kB)
# Downloading sne4onnx-1.0.13-py3-none-any.whl (7.2 kB)
# Downloading sng4onnx-1.0.4-py3-none-any.whl (5.9 kB)
# Downloading soa4onnx-1.0.4-py3-none-any.whl (6.3 kB)
# Downloading soc4onnx-1.0.2-py3-none-any.whl (5.7 kB)
# Downloading sod4onnx-1.0.0-py3-none-any.whl (5.9 kB)
# Downloading sog4onnx-1.0.17-py3-none-any.whl (9.7 kB)
# Downloading sor4onnx-1.0.7-py3-none-any.whl (7.3 kB)
# Downloading spo4onnx-1.0.5-py3-none-any.whl (11 kB)
# Downloading ssc4onnx-1.0.8-py3-none-any.whl (6.6 kB)
# Downloading ssi4onnx-1.0.4-py3-none-any.whl (5.7 kB)
# Downloading svs4onnx-1.0.0-py3-none-any.whl (6.3 kB)
# Installing collected packages: svs4onnx, ssi4onnx, ssc4onnx, spo4onnx, sor4onnx, sog4onnx, sod4onnx, soc4onnx, soa4onnx, sng4onnx, sne4onnx, snd4onnx, snc4onnx, sit4onnx, sio4onnx, sed4onnx, sde4onnx, scs4onnx, scc4onnx, sbi4onnx, sam4onnx, onnx2json, json2onnx, sna4onnx, simple_onnx_processing_tools
#
#    - --------------------------------------  1/25 [ssi4onnx]
#    --- ------------------------------------  2/25 [ssc4onnx]
#    ------ ---------------------------------  4/25 [sor4onnx]
#    -------- -------------------------------  5/25 [sog4onnx]
#    ----------- ----------------------------  7/25 [soc4onnx]
#    ------------ ---------------------------  8/25 [soa4onnx]
#    -------------- -------------------------  9/25 [sng4onnx]
#    ----------------- ---------------------- 11/25 [snd4onnx]
#    ------------------- -------------------- 12/25 [snc4onnx]
#    ---------------------- ----------------- 14/25 [sio4onnx]
#    ------------------------ --------------- 15/25 [sed4onnx]
#    ------------------------- -------------- 16/25 [sde4onnx]
#    --------------------------- ------------ 17/25 [scs4onnx]
#    ------------------------------ --------- 19/25 [sbi4onnx]
#    -------------------------------- ------- 20/25 [sam4onnx]
#    --------------------------------- ------ 21/25 [onnx2json]
#    ------------------------------------ --- 23/25 [sna4onnx]
#    --------------------------------------- 25/25 [simple_onnx_processing_tools]
#
# Successfully installed json2onnx-2.0.3 onnx2json-2.0.4 sam4onnx-1.0.16 sbi4onnx-1.0.7 scc4onnx-1.0.7 scs4onnx-1.0.18 sde4onnx-1.0.0 sed4onnx-1.0.5 simple_onnx_processing_tools-1.1.32 sio4onnx-1.0.3 sit4onnx-1.0.8 sna4onnx-1.0.6 snc4onnx-1.0.13 snd4onnx-1.1.6 sne4onnx-1.0.13 sng4onnx-1.0.4 soa4onnx-1.0.4 soc4onnx-1.0.2 sod4onnx-1.0.0 sog4onnx-1.0.17 sor4onnx-1.0.7 spo4onnx-1.0.5 ssc4onnx-1.0.8 ssi4onnx-1.0.4 svs4onnx-1.0.0
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement ai_edge_litert==1.2.0 (from versions: none)
# ERROR: No matching distribution found for ai_edge_litert==1.2.0
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: tensorflow==2.19.0 in c:\arf\my-repos\magang\.venv\lib\site-packages (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\arf\my-repos\magang\.venv\lib\site-packages (from tensorflow==2.19.0) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\arf\my-repos\magang\.venv\lib\site-packages (from tensorflow==2.19.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\arf\my-repos\magang\.venv\lib\site-packages (from tensorflow==2.19.0) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\arf\my-repos\magang\.venv\lib\site-packages (from tensorflow==2.19.0) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\arf\my-repos\magang\.venv\lib\site-packages (from tensorflow==2.19.0) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\arf\my-repos\magang\.venv\lib\site-packages (from tensorflow==2.19.0) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\arf\my-repos\magang\.venv\lib\site-packages (from tensorflow==2.19.0) (3.4.0)
# Requirement already satisfied: packaging in c:\arf\my-repos\magang\.venv\lib\site-packages (from tensorflow==2.19.0) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\arf\my-repos\magang\.venv\lib\site-packages (from tensorflow==2.19.0) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\arf\my-repos\magang\.venv\lib\site-packages (from tensorflow==2.19.0) (2.32.4)
# Requirement already satisfied: setuptools in c:\arf\my-repos\magang\.venv\lib\site-packages (from tensorflow==2.19.0) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\arf\my-repos\magang\.venv\lib\site-packages (from tensorflow==2.19.0) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\arf\my-repos\magang\.venv\lib\site-packages (from tensorflow==2.19.0) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\arf\my-repos\magang\.venv\lib\site-packages (from tensorflow==2.19.0) (4.14.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\arf\my-repos\magang\.venv\lib\site-packages (from tensorflow==2.19.0) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\arf\my-repos\magang\.venv\lib\site-packages (from tensorflow==2.19.0) (1.73.1)
# Requirement already satisfied: tensorboard~=2.19.0 in c:\arf\my-repos\magang\.venv\lib\site-packages (from tensorflow==2.19.0) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in c:\arf\my-repos\magang\.venv\lib\site-packages (from tensorflow==2.19.0) (3.10.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in c:\arf\my-repos\magang\.venv\lib\site-packages (from tensorflow==2.19.0) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\arf\my-repos\magang\.venv\lib\site-packages (from tensorflow==2.19.0) (3.14.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in c:\arf\my-repos\magang\.venv\lib\site-packages (from tensorflow==2.19.0) (0.5.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\arf\my-repos\magang\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow==2.19.0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\arf\my-repos\magang\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow==2.19.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\arf\my-repos\magang\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow==2.19.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\arf\my-repos\magang\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow==2.19.0) (2025.7.14)
# Requirement already satisfied: markdown>=2.6.8 in c:\arf\my-repos\magang\.venv\lib\site-packages (from tensorboard~=2.19.0->tensorflow==2.19.0) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\arf\my-repos\magang\.venv\lib\site-packages (from tensorboard~=2.19.0->tensorflow==2.19.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\arf\my-repos\magang\.venv\lib\site-packages (from tensorboard~=2.19.0->tensorflow==2.19.0) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\arf\my-repos\magang\.venv\lib\site-packages (from astunparse>=1.6.0->tensorflow==2.19.0) (0.45.1)
# Requirement already satisfied: rich in c:\arf\my-repos\magang\.venv\lib\site-packages (from keras>=3.5.0->tensorflow==2.19.0) (14.0.0)
# Requirement already satisfied: namex in c:\arf\my-repos\magang\.venv\lib\site-packages (from keras>=3.5.0->tensorflow==2.19.0) (0.1.0)
# Requirement already satisfied: optree in c:\arf\my-repos\magang\.venv\lib\site-packages (from keras>=3.5.0->tensorflow==2.19.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\arf\my-repos\magang\.venv\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow==2.19.0) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\arf\my-repos\magang\.venv\lib\site-packages (from rich->keras>=3.5.0->tensorflow==2.19.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\arf\my-repos\magang\.venv\lib\site-packages (from rich->keras>=3.5.0->tensorflow==2.19.0) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\arf\my-repos\magang\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow==2.19.0) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting protobuf==3.20.3
#   Downloading protobuf-3.20.3-py2.py3-none-any.whl.metadata (720 bytes)
# Downloading protobuf-3.20.3-py2.py3-none-any.whl (162 kB)
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.5
#     Uninstalling protobuf-5.29.5:
#       Successfully uninstalled protobuf-5.29.5
# Successfully installed protobuf-3.20.3
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'C:\ARF\my-repos\magang\.venv\Lib\site-packages\google\~upb'.
#   You can safely remove it manually.
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: onnx2tf in c:\arf\my-repos\magang\.venv\lib\site-packages (1.28.2)
# Note: you may need to restart the kernel to use updated packages.
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting h5py==3.11.0
#   Downloading h5py-3.11.0-cp312-cp312-win_amd64.whl.metadata (2.5 kB)
# Requirement already satisfied: numpy>=1.17.3 in c:\arf\my-repos\magang\.venv\lib\site-packages (from h5py==3.11.0) (1.26.4)
# Downloading h5py-3.11.0-cp312-cp312-win_amd64.whl (3.0 MB)
#    ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#    -------------- ------------------------- 1.0/3.0 MB 8.4 MB/s eta 0:00:01
#    ---------------------------------------- 3.0/3.0 MB 13.3 MB/s eta 0:00:00
# Installing collected packages: h5py
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.14.0
#     Uninstalling h5py-3.14.0:
#       Successfully uninstalled h5py-3.14.0
# Successfully installed h5py-3.11.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'C:\ARF\my-repos\magang\.venv\Lib\site-packages\~5py'.
#   You can safely remove it manually.
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting psutil==5.9.5
#   Downloading psutil-5.9.5-cp36-abi3-win_amd64.whl.metadata (21 kB)
# Downloading psutil-5.9.5-cp36-abi3-win_amd64.whl (255 kB)
# Installing collected packages: psutil
#   Attempting uninstall: psutil
#     Found existing installation: psutil 7.0.0
#     Uninstalling psutil-7.0.0:
#       Successfully uninstalled psutil-7.0.0
# Successfully installed psutil-5.9.5
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'C:\ARF\my-repos\magang\.venv\Lib\site-packages\~sutil'.
#   You can safely remove it manually.
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: ml_dtypes==0.5.1 in c:\arf\my-repos\magang\.venv\lib\site-packages (0.5.1)
# Requirement already satisfied: numpy>=1.21 in c:\arf\my-repos\magang\.venv\lib\site-packages (from ml_dtypes==0.5.1) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: tf-keras==2.19.0 in c:\arf\my-repos\magang\.venv\lib\site-packages (2.19.0)
# Requirement already satisfied: tensorflow<2.20,>=2.19 in c:\arf\my-repos\magang\.venv\lib\site-packages (from tf-keras==2.19.0) (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\arf\my-repos\magang\.venv\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras==2.19.0) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\arf\my-repos\magang\.venv\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras==2.19.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\arf\my-repos\magang\.venv\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras==2.19.0) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\arf\my-repos\magang\.venv\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras==2.19.0) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\arf\my-repos\magang\.venv\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras==2.19.0) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\arf\my-repos\magang\.venv\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras==2.19.0) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\arf\my-repos\magang\.venv\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras==2.19.0) (3.4.0)
# Requirement already satisfied: packaging in c:\arf\my-repos\magang\.venv\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras==2.19.0) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\arf\my-repos\magang\.venv\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras==2.19.0) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\arf\my-repos\magang\.venv\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras==2.19.0) (2.32.4)
# Requirement already satisfied: setuptools in c:\arf\my-repos\magang\.venv\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras==2.19.0) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\arf\my-repos\magang\.venv\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras==2.19.0) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\arf\my-repos\magang\.venv\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras==2.19.0) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\arf\my-repos\magang\.venv\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras==2.19.0) (4.14.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\arf\my-repos\magang\.venv\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras==2.19.0) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\arf\my-repos\magang\.venv\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras==2.19.0) (1.73.1)
# Requirement already satisfied: tensorboard~=2.19.0 in c:\arf\my-repos\magang\.venv\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras==2.19.0) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in c:\arf\my-repos\magang\.venv\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras==2.19.0) (3.10.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in c:\arf\my-repos\magang\.venv\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras==2.19.0) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\arf\my-repos\magang\.venv\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras==2.19.0) (3.11.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in c:\arf\my-repos\magang\.venv\lib\site-packages (from tensorflow<2.20,>=2.19->tf-keras==2.19.0) (0.5.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\arf\my-repos\magang\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras==2.19.0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\arf\my-repos\magang\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras==2.19.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\arf\my-repos\magang\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras==2.19.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\arf\my-repos\magang\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras==2.19.0) (2025.7.14)
# Requirement already satisfied: markdown>=2.6.8 in c:\arf\my-repos\magang\.venv\lib\site-packages (from tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras==2.19.0) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\arf\my-repos\magang\.venv\lib\site-packages (from tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras==2.19.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\arf\my-repos\magang\.venv\lib\site-packages (from tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras==2.19.0) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\arf\my-repos\magang\.venv\lib\site-packages (from astunparse>=1.6.0->tensorflow<2.20,>=2.19->tf-keras==2.19.0) (0.45.1)
# Requirement already satisfied: rich in c:\arf\my-repos\magang\.venv\lib\site-packages (from keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras==2.19.0) (14.0.0)
# Requirement already satisfied: namex in c:\arf\my-repos\magang\.venv\lib\site-packages (from keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras==2.19.0) (0.1.0)
# Requirement already satisfied: optree in c:\arf\my-repos\magang\.venv\lib\site-packages (from keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras==2.19.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\arf\my-repos\magang\.venv\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras==2.19.0) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\arf\my-repos\magang\.venv\lib\site-packages (from rich->keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras==2.19.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\arf\my-repos\magang\.venv\lib\site-packages (from rich->keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras==2.19.0) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\arf\my-repos\magang\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras==2.19.0) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
